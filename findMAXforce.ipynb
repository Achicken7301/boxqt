# %%
import time
import pandas as pd
import csv

# %% [markdown]
# # Tìm max

# %%
df = pd.read_csv("D:\laragon\www\\boxqt\data\data_1kohms_310Hz\\raw\done_50_punches_data2 11-07-22 13-34-45.csv", index_col=False)
df = df['f']

# %%
punch = []
max_punch = []
raw_data = df.values
for i in raw_data:
    if i == 0:
        if len(punch) != 0:
            # print("check if max > 1000")
            if max(punch) > 1000:
                # print("correct")
                print(punch)
                max_punch.append(max(punch))
                print(max(punch))
                punch = []
            else:
                # print("wrong")
                punch = []
    else:
        punch.append(i)

# print(max_punch)
# Out:
# [211, 409, 640, 1462, 1490, 1570, 1551, 1522, 1472, 1447, 1414, 1371, 1302, 1229, 1122, 1020, 933, 871, 757, 689, 602, 527, 432, 390, 346, 334, 297, 223, 205, 132, 80, 39, 38, 19, 4]
# 1570
# ...
