# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
path = r"D:\laragon\www\boxqt\boxing-gui\Profies\User\total\total.xlsx"
data = pd.read_excel(path)

# %%
data
# Out:
#         a_std     g_std     g_max  force(model)  force(analog)  \
# 0    2.556005  0.118256  0.098673      5.075454          213.0
# 1    2.955693  0.124242  0.104571      5.489118          458.0
# 2    2.419803  0.124957  0.139347      5.540502          173.0
# 3    2.795615  0.138557  0.111620      6.549528          435.0
# 4    2.335104  0.149436  0.113312      6.942800          165.0
# ..        ...       ...       ...           ...            ...
# 90  14.952872  0.884233  0.840975     19.898806          848.0
# 91  15.549579  0.965570  0.985134     20.742649          906.0
# 92  16.510267  1.023576  0.988618     21.303282          883.0
# 93  17.338506  1.029193  0.886077     21.354406          830.0
# 94        NaN       NaN       NaN           NaN            NaN
#
#     force(loadcell)  force(theory)  diff(model vs theory)  \
# 0            5.7871      28.368570              23.293116
# 1           13.9946      30.064042              24.574924
# ...

# %%
# create Bland-Altman plot
f, ax = plt.subplots(1, figsize=(10, 5))
sm.graphics.mean_diff_plot(data["force(loadcell)"], data["force(theory)"], ax=ax)

# display Bland-Altman plot
plt.show()

# %%
# create Bland-Altman plot
f, ax = plt.subplots(1, figsize=(10, 5))
sm.graphics.mean_diff_plot(data["force(model)"], data["force(theory)"], ax=ax)

# display Bland-Altman plot
plt.show()

# %%
#create Bland-Altman plot                  
f, ax = plt.subplots(1, figsize = (8,5))
sm.graphics.mean_diff_plot(data['force(model)'], data['force(loadcell)'], ax = ax)

#display Bland-Altman plot
plt.show()
